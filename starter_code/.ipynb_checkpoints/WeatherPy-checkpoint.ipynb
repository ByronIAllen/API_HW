# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Base url
unit = "imperial"
url = f"http://api.openweathermap.org/data/2.5/weather?units={unit}&appid={api_key}&q="

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# JSON code/indices check
requests.get(url + cities[0]).json()
# Out:
# {'coord': {'lon': -147.72, 'lat': 64.84},
#  'weather': [{'id': 701,
#    'main': 'Mist',
#    'description': 'mist',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 30.79,
#   'pressure': 1004,
#   'humidity': 100,
#   'temp_min': 30.2,
#   'temp_max': 32},
#  'visibility': 16093,
#  'wind': {'speed': 4.7, 'deg': 40},
#  'clouds': {'all': 90},
#  'dt': 1540673880,
#  'sys': {'type': 1,
#   'id': 63,
#   'message': 0.0037,
#   'country': 'US',
#   'sunrise': 1540661140,
#   'sunset': 1540690942},
#  'id': 5861897,
#  'name': 'Fairbanks',
#  'cod': 200}

# %%
print("Beginning Data Retrieval")
print("-----------------------------")

weather_info = []
record = 1
set_number = 1

for city in cities:
    response = requests.get(url + city)
    if response.status_code == 200:
        response_json = response.json()
        weather_info.append([city, response_json["clouds"]["all"], 
                             response_json["sys"]["country"], 
                             response_json["dt"], 
                             response_json["main"]["humidity"], 
                             response_json["coord"]["lat"],
                             response_json["coord"]["lon"],
                             response_json["main"]["temp_max"], 
                             response_json["wind"]["speed"]                             
                            ])
        
        print(f"Processing Record {record} of Set {set_number} | {city}")
        
        if record < 50:
            record = record + 1
        elif record >= 50:
            record = 1
            set_number = set_number + 1
        
    else:
        print("City not found. Skipping...")
        
    time.sleep(1.1)
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | fairbanks
# Processing Record 2 of Set 1 | kruisfontein
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | yellowknife
# Processing Record 5 of Set 1 | tiarei
# Processing Record 6 of Set 1 | nanae
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | porto walter
# Processing Record 14 of Set 1 | vilyuysk
# Processing Record 15 of Set 1 | lavrentiya
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | busselton
# Processing Record 21 of Set 1 | mar del plata
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | leshukonskoye
# Processing Record 24 of Set 1 | ardrishaig
# Processing Record 25 of Set 1 | east london
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | sao jose da coroa grande
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | batagay-alyta
# Processing Record 31 of Set 1 | kuusamo
# Processing Record 32 of Set 1 | smithers
# Processing Record 33 of Set 1 | najran
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | katsuura
# Processing Record 36 of Set 1 | carnarvon
# Processing Record 37 of Set 1 | george town
# Processing Record 38 of Set 1 | killybegs
# Processing Record 39 of Set 1 | saskylakh
# City not found. Skipping...
# Processing Record 40 of Set 1 | hithadhoo
# Processing Record 41 of Set 1 | vaini
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | qaanaaq
# Processing Record 44 of Set 1 | eichstatt
# Processing Record 45 of Set 1 | torbay
# Processing Record 46 of Set 1 | nunchia
# Processing Record 47 of Set 1 | bathsheba
# Processing Record 48 of Set 1 | lorengau
# Processing Record 49 of Set 1 | ostersund
# Processing Record 50 of Set 1 | hermanus
# Processing Record 1 of Set 2 | gat
# Processing Record 2 of Set 2 | micheweni
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | christchurch
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | cherskiy
# Processing Record 9 of Set 2 | norman wells
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | barinas
# Processing Record 12 of Set 2 | port elizabeth
# Processing Record 13 of Set 2 | port alfred
# Processing Record 14 of Set 2 | tiksi
# City not found. Skipping...
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | pucallpa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 2 | grand gaube
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | guerrero negro
# City not found. Skipping...
# Processing Record 21 of Set 2 | akdagmadeni
# Processing Record 22 of Set 2 | half moon bay
# Processing Record 23 of Set 2 | saint-philippe
# Processing Record 24 of Set 2 | hambantota
# Processing Record 25 of Set 2 | nortelandia
# Processing Record 26 of Set 2 | alofi
# Processing Record 27 of Set 2 | kavieng
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | impfondo
# Processing Record 30 of Set 2 | talnakh
# City not found. Skipping...
# Processing Record 31 of Set 2 | okhotsk
# Processing Record 32 of Set 2 | cantagallo
# City not found. Skipping...
# Processing Record 33 of Set 2 | kokopo
# Processing Record 34 of Set 2 | jamestown
# Processing Record 35 of Set 2 | deputatskiy
# Processing Record 36 of Set 2 | lazaro cardenas
# Processing Record 37 of Set 2 | ovada
# Processing Record 38 of Set 2 | batemans bay
# Processing Record 39 of Set 2 | hamilton
# Processing Record 40 of Set 2 | dingle
# Processing Record 41 of Set 2 | provideniya
# City not found. Skipping...
# Processing Record 42 of Set 2 | port lincoln
# Processing Record 43 of Set 2 | itoman
# Processing Record 44 of Set 2 | tomislavgrad
# Processing Record 45 of Set 2 | campoverde
# Processing Record 46 of Set 2 | laela
# Processing Record 47 of Set 2 | havre-saint-pierre
# Processing Record 48 of Set 2 | la tuque
# Processing Record 49 of Set 2 | yar-sale
# Processing Record 50 of Set 2 | bambous virieux
# Processing Record 1 of Set 3 | vila franca do campo
# Processing Record 2 of Set 3 | vestmannaeyjar
# Processing Record 3 of Set 3 | sai buri
# Processing Record 4 of Set 3 | bogande
# Processing Record 5 of Set 3 | jacksonville
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | faanui
# Processing Record 8 of Set 3 | goedereede
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | massakory
# Processing Record 11 of Set 3 | arraial do cabo
# Processing Record 12 of Set 3 | pacific grove
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | maldonado
# City not found. Skipping...
# Processing Record 15 of Set 3 | tibati
# Processing Record 16 of Set 3 | teguise
# Processing Record 17 of Set 3 | aksu
# Processing Record 18 of Set 3 | camacha
# Processing Record 19 of Set 3 | zhanakorgan
# City not found. Skipping...
# Processing Record 20 of Set 3 | dong hoi
# Processing Record 21 of Set 3 | port macquarie
# Processing Record 22 of Set 3 | marion
# City not found. Skipping...
# Processing Record 23 of Set 3 | mae sot
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 3 | sao joao de pirabas
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | killorglin
# Processing Record 27 of Set 3 | portland
# Processing Record 28 of Set 3 | grand-santi
# Processing Record 29 of Set 3 | dabakala
# City not found. Skipping...
# Processing Record 30 of Set 3 | vila
# Processing Record 31 of Set 3 | butaritari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 3 | terrace
# Processing Record 33 of Set 3 | karratha
# City not found. Skipping...
# Processing Record 34 of Set 3 | faya
# Processing Record 35 of Set 3 | wanaka
# Processing Record 36 of Set 3 | araouane
# Processing Record 37 of Set 3 | zhezkazgan
# Processing Record 38 of Set 3 | dhidhdhoo
# City not found. Skipping...
# Processing Record 39 of Set 3 | dobanovci
# Processing Record 40 of Set 3 | yeppoon
# Processing Record 41 of Set 3 | ballina
# Processing Record 42 of Set 3 | kavaratti
# Processing Record 43 of Set 3 | muisne
# City not found. Skipping...
# Processing Record 44 of Set 3 | hirara
# City not found. Skipping...
# Processing Record 45 of Set 3 | nouadhibou
# Processing Record 46 of Set 3 | sinnamary
# Processing Record 47 of Set 3 | egvekinot
# Processing Record 48 of Set 3 | shirpur
# Processing Record 49 of Set 3 | baturaja
# City not found. Skipping...
# Processing Record 50 of Set 3 | salalah
# Processing Record 1 of Set 4 | hasaki
# Processing Record 2 of Set 4 | lebu
# Processing Record 3 of Set 4 | ponta do sol
# Processing Record 4 of Set 4 | saint anthony
# Processing Record 5 of Set 4 | sangar
# Processing Record 6 of Set 4 | kiunga
# Processing Record 7 of Set 4 | marawi
# Processing Record 8 of Set 4 | itaituba
# Processing Record 9 of Set 4 | carupano
# Processing Record 10 of Set 4 | shu
# City not found. Skipping...
# Processing Record 11 of Set 4 | mogadishu
# Processing Record 12 of Set 4 | praya
# Processing Record 13 of Set 4 | te anau
# Processing Record 14 of Set 4 | paramonga
# Processing Record 15 of Set 4 | ust-kulom
# Processing Record 16 of Set 4 | biak
# Processing Record 17 of Set 4 | jalu
# Processing Record 18 of Set 4 | lugoba
# Processing Record 19 of Set 4 | neiafu
# Processing Record 20 of Set 4 | longyearbyen
# Processing Record 21 of Set 4 | bluff
# Processing Record 22 of Set 4 | bonthe
# Processing Record 23 of Set 4 | mihaesti
# Processing Record 24 of Set 4 | fukue
# Processing Record 25 of Set 4 | terra santa
# City not found. Skipping...
# Processing Record 26 of Set 4 | kibuye
# Processing Record 27 of Set 4 | victoria
# Processing Record 28 of Set 4 | preobrazheniye
# City not found. Skipping...
# Processing Record 29 of Set 4 | kendari
# Processing Record 30 of Set 4 | cockburn town
# Processing Record 31 of Set 4 | iracoubo
# Processing Record 32 of Set 4 | kaeo
# Processing Record 33 of Set 4 | ialibu
# City not found. Skipping...
# Processing Record 34 of Set 4 | coihueco
# City not found. Skipping...
# Processing Record 35 of Set 4 | la palma
# Processing Record 36 of Set 4 | nanortalik
# Processing Record 37 of Set 4 | sorland
# City not found. Skipping...
# Processing Record 38 of Set 4 | ahipara
# Processing Record 39 of Set 4 | alexandria
# Processing Record 40 of Set 4 | northam
# Processing Record 41 of Set 4 | kungurtug
# Processing Record 42 of Set 4 | wencheng
# Processing Record 43 of Set 4 | karlstadt
# Processing Record 44 of Set 4 | mattru
# Processing Record 45 of Set 4 | bogatyye saby
# Processing Record 46 of Set 4 | bogale
# City not found. Skipping...
# Processing Record 47 of Set 4 | mahibadhoo
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | clyde river
# Processing Record 50 of Set 4 | alekseyevskoye
# Processing Record 1 of Set 5 | orizona
# Processing Record 2 of Set 5 | schleswig
# Processing Record 3 of Set 5 | shitanjing
# Processing Record 4 of Set 5 | mega
# Processing Record 5 of Set 5 | aklavik
# Processing Record 6 of Set 5 | timizart
# Processing Record 7 of Set 5 | puri
# Processing Record 8 of Set 5 | mataura
# Processing Record 9 of Set 5 | penzance
# Processing Record 10 of Set 5 | nieuw amsterdam
# Processing Record 11 of Set 5 | rawson
# Processing Record 12 of Set 5 | dickinson
# Processing Record 13 of Set 5 | purpe
# City not found. Skipping...
# Processing Record 14 of Set 5 | gizo
# Processing Record 15 of Set 5 | sirpur
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | oranjemund
# Processing Record 18 of Set 5 | tweed
# Processing Record 19 of Set 5 | tocopilla
# Processing Record 20 of Set 5 | inawashiro
# Processing Record 21 of Set 5 | chicama
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | kudahuvadhoo
# Processing Record 24 of Set 5 | praia
# Processing Record 25 of Set 5 | anloga
# Processing Record 26 of Set 5 | takaka
# Processing Record 27 of Set 5 | dayong
# Processing Record 28 of Set 5 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 29 of Set 5 | ouadda
# Processing Record 30 of Set 5 | senno
# Processing Record 31 of Set 5 | ilulissat
# City not found. Skipping...
# Processing Record 32 of Set 5 | celestun
# Processing Record 33 of Set 5 | touros
# Processing Record 34 of Set 5 | fernley
# Processing Record 35 of Set 5 | jumla
# Processing Record 36 of Set 5 | san patricio
# Processing Record 37 of Set 5 | gisborne
# Processing Record 38 of Set 5 | jutai
# Processing Record 39 of Set 5 | thaba nchu
# Processing Record 40 of Set 5 | maravilha
# Processing Record 41 of Set 5 | sorgun
# Processing Record 42 of Set 5 | fernie
# Processing Record 43 of Set 5 | pokhara
# Processing Record 44 of Set 5 | vuktyl
# Processing Record 45 of Set 5 | tilichiki
# Processing Record 46 of Set 5 | bintulu
# Processing Record 47 of Set 5 | saint-pierre
# Processing Record 48 of Set 5 | kinshasa
# Processing Record 49 of Set 5 | namibe
# Processing Record 50 of Set 5 | solnechnyy
# Processing Record 1 of Set 6 | shingu
# Processing Record 2 of Set 6 | tongliao
# Processing Record 3 of Set 6 | poplar bluff
# Processing Record 4 of Set 6 | haverfordwest
# Processing Record 5 of Set 6 | omsukchan
# City not found. Skipping...
# Processing Record 6 of Set 6 | rosarito
# Processing Record 7 of Set 6 | severo-kurilsk
# Processing Record 8 of Set 6 | te karaka
# Processing Record 9 of Set 6 | kedrovyy
# Processing Record 10 of Set 6 | mantua
# Processing Record 11 of Set 6 | longyan
# Processing Record 12 of Set 6 | pangoa
# Processing Record 13 of Set 6 | meulaboh
# Processing Record 14 of Set 6 | souillac
# Processing Record 15 of Set 6 | qasigiannguit
# Processing Record 16 of Set 6 | goma
# Processing Record 17 of Set 6 | vila velha
# Processing Record 18 of Set 6 | dekar
# Processing Record 19 of Set 6 | narsaq
# City not found. Skipping...
# Processing Record 20 of Set 6 | saint-leu
# Processing Record 21 of Set 6 | mwinilunga
# City not found. Skipping...
# Processing Record 22 of Set 6 | fairview
# Processing Record 23 of Set 6 | baykit
# Processing Record 24 of Set 6 | namatanai
# Processing Record 25 of Set 6 | binzhou
# Processing Record 26 of Set 6 | gardner
# Processing Record 27 of Set 6 | north bend
# Processing Record 28 of Set 6 | birao
# Processing Record 29 of Set 6 | cururupu
# Processing Record 30 of Set 6 | yerbogachen
# Processing Record 31 of Set 6 | monster
# Processing Record 32 of Set 6 | zelenogorskiy
# Processing Record 33 of Set 6 | katobu
# Processing Record 34 of Set 6 | clovis
# Processing Record 35 of Set 6 | meadow lake
# Processing Record 36 of Set 6 | xixiang
# Processing Record 37 of Set 6 | great bend
# Processing Record 38 of Set 6 | yeniseysk
# Processing Record 39 of Set 6 | arcos de la frontera
# Processing Record 40 of Set 6 | minas
# Processing Record 41 of Set 6 | bandar
# Processing Record 42 of Set 6 | glenwood springs
# Processing Record 43 of Set 6 | ferrol
# Processing Record 44 of Set 6 | igrim
# Processing Record 45 of Set 6 | axim
# Processing Record 46 of Set 6 | cookeville
# Processing Record 47 of Set 6 | alvdal
# Processing Record 48 of Set 6 | upernavik
# City not found. Skipping...
# Processing Record 49 of Set 6 | husavik
# Processing Record 50 of Set 6 | makinsk
# City not found. Skipping...
# Processing Record 1 of Set 7 | uribia
# Processing Record 2 of Set 7 | nelson bay
# Processing Record 3 of Set 7 | xinzhou
# City not found. Skipping...
# Processing Record 4 of Set 7 | santa fe
# Processing Record 5 of Set 7 | prince rupert
# Processing Record 6 of Set 7 | pringsewu
# Processing Record 7 of Set 7 | buraydah
# Processing Record 8 of Set 7 | ostrovnoy
# Processing Record 9 of Set 7 | fort stewart
# Processing Record 10 of Set 7 | vestmanna
# Processing Record 11 of Set 7 | bethlehem
# Processing Record 12 of Set 7 | harper
# Processing Record 13 of Set 7 | cidreira
# Processing Record 14 of Set 7 | klaksvik
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | ovalle
# Processing Record 17 of Set 7 | mount isa
# Processing Record 18 of Set 7 | zhuanghe
# Processing Record 19 of Set 7 | xining
# Processing Record 20 of Set 7 | nizhniy kuranakh
# Processing Record 21 of Set 7 | campbell river
# City not found. Skipping...
# Processing Record 22 of Set 7 | saint george
# Processing Record 23 of Set 7 | midland
# Processing Record 24 of Set 7 | mahebourg
# Processing Record 25 of Set 7 | codrington
# Processing Record 26 of Set 7 | luena
# Processing Record 27 of Set 7 | ginda
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 7 | araguaina
# Processing Record 29 of Set 7 | mareeba
# Processing Record 30 of Set 7 | rehoboth
# Processing Record 31 of Set 7 | nome
# Processing Record 32 of Set 7 | kindu
# Processing Record 33 of Set 7 | vao
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | paita
# Processing Record 36 of Set 7 | tarsus
# Processing Record 37 of Set 7 | kalmunai
# Processing Record 38 of Set 7 | creel
# Processing Record 39 of Set 7 | port hedland
# Processing Record 40 of Set 7 | arshan
# Processing Record 41 of Set 7 | inhambane
# City not found. Skipping...
# Processing Record 42 of Set 7 | kasongo
# Processing Record 43 of Set 7 | opuwo
# Processing Record 44 of Set 7 | abu samrah
# Processing Record 45 of Set 7 | ancud
# Processing Record 46 of Set 7 | westport
# City not found. Skipping...
# Processing Record 47 of Set 7 | san quintin
# Processing Record 48 of Set 7 | bukama
# Processing Record 49 of Set 7 | pershotravneve
# Processing Record 50 of Set 7 | znamenskoye
# Processing Record 1 of Set 8 | tiznit
# Processing Record 2 of Set 8 | ferkessedougou
# Processing Record 3 of Set 8 | bagdarin
# Processing Record 4 of Set 8 | natitingou
# Processing Record 5 of Set 8 | canico
# Processing Record 6 of Set 8 | lokosovo
# Processing Record 7 of Set 8 | port-gentil
# Processing Record 8 of Set 8 | doha
# Processing Record 9 of Set 8 | sept-iles
# Processing Record 10 of Set 8 | kolosovka
# Processing Record 11 of Set 8 | elko
# Processing Record 12 of Set 8 | calafell
# Processing Record 13 of Set 8 | ust-kan
# Processing Record 14 of Set 8 | yebaishou
# Processing Record 15 of Set 8 | kahului
# Processing Record 16 of Set 8 | lonar
# Processing Record 17 of Set 8 | suhut
# Processing Record 18 of Set 8 | komsomolskiy
# Processing Record 19 of Set 8 | cabinda
# Processing Record 20 of Set 8 | zaqatala
# Processing Record 21 of Set 8 | yen bai
# Processing Record 22 of Set 8 | yasnyy
# Processing Record 23 of Set 8 | sola
# Processing Record 24 of Set 8 | pampa
# Processing Record 25 of Set 8 | nizhnyaya tavda
# Processing Record 26 of Set 8 | kiama
# Processing Record 27 of Set 8 | broken hill
# Processing Record 28 of Set 8 | genhe
# Processing Record 29 of Set 8 | flinders
# Processing Record 30 of Set 8 | beringovskiy
# Processing Record 31 of Set 8 | wamba
# Processing Record 32 of Set 8 | forestville
# Processing Record 33 of Set 8 | khatanga
# Processing Record 34 of Set 8 | rocha
# Processing Record 35 of Set 8 | necochea
# Processing Record 36 of Set 8 | chara
# Processing Record 37 of Set 8 | urbano santos
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | todos santos
# Processing Record 40 of Set 8 | luderitz
# Processing Record 41 of Set 8 | bam
# Processing Record 42 of Set 8 | luneville
# Processing Record 43 of Set 8 | marsh harbour
# Processing Record 44 of Set 8 | esna
# Processing Record 45 of Set 8 | brigantine
# Processing Record 46 of Set 8 | jaca
# Processing Record 47 of Set 8 | tokonou
# Processing Record 48 of Set 8 | bilma
# Processing Record 49 of Set 8 | nong han
# Processing Record 50 of Set 8 | isangel
# Processing Record 1 of Set 9 | vardo
# City not found. Skipping...
# Processing Record 2 of Set 9 | aleksandrov gay
# Processing Record 3 of Set 9 | saquena
# Processing Record 4 of Set 9 | ambovombe
# Processing Record 5 of Set 9 | moose factory
# Processing Record 6 of Set 9 | ambikapur
# Processing Record 7 of Set 9 | nang rong
# City not found. Skipping...
# Processing Record 8 of Set 9 | teknaf
# Processing Record 9 of Set 9 | muros
# Processing Record 10 of Set 9 | santa maria
# Processing Record 11 of Set 9 | bandarbeyla
# Processing Record 12 of Set 9 | saint-denis
# Processing Record 13 of Set 9 | anadyr
# Processing Record 14 of Set 9 | porbandar
# City not found. Skipping...
# Processing Record 15 of Set 9 | mildura
# Processing Record 16 of Set 9 | tezu
# Processing Record 17 of Set 9 | mayo
# City not found. Skipping...
# Processing Record 18 of Set 9 | laguna
# Processing Record 19 of Set 9 | sawakin
# Processing Record 20 of Set 9 | jiexiu
# Processing Record 21 of Set 9 | ribeira grande
# Processing Record 22 of Set 9 | pangnirtung
# City not found. Skipping...
# Processing Record 23 of Set 9 | gornopravdinsk
# Processing Record 24 of Set 9 | sarangani
# City not found. Skipping...
# Processing Record 25 of Set 9 | palana
# City not found. Skipping...
# Processing Record 26 of Set 9 | madison
# Processing Record 27 of Set 9 | uige
# Processing Record 28 of Set 9 | taree
# Processing Record 29 of Set 9 | paka
# Processing Record 30 of Set 9 | altay
# Processing Record 31 of Set 9 | arlit
# Processing Record 32 of Set 9 | winneba
# City not found. Skipping...
# Processing Record 33 of Set 9 | carauari
# Processing Record 34 of Set 9 | fort frances
# Processing Record 35 of Set 9 | morant bay
# Processing Record 36 of Set 9 | manggar
# Processing Record 37 of Set 9 | cordoba
# Processing Record 38 of Set 9 | barra do garcas
# Processing Record 39 of Set 9 | jimenez
# Processing Record 40 of Set 9 | vostok
# Processing Record 41 of Set 9 | zalantun
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | tigil
# Processing Record 44 of Set 9 | kaitangata
# Processing Record 45 of Set 9 | ati
# Processing Record 46 of Set 9 | mitu
# Processing Record 47 of Set 9 | tefe
# Processing Record 48 of Set 9 | chegdomyn
# Processing Record 49 of Set 9 | los llanos de aridane
# Processing Record 50 of Set 9 | ponta delgada
# Processing Record 1 of Set 10 | moen
# Processing Record 2 of Set 10 | ixtapa
# Processing Record 3 of Set 10 | ribeira brava
# City not found. Skipping...
# Processing Record 4 of Set 10 | tateyama
# Processing Record 5 of Set 10 | merauke
# Processing Record 6 of Set 10 | beaverlodge
# Processing Record 7 of Set 10 | dudinka
# Processing Record 8 of Set 10 | taoudenni
# Processing Record 9 of Set 10 | tual
# Processing Record 10 of Set 10 | srednekolymsk
# Processing Record 11 of Set 10 | otane
# Processing Record 12 of Set 10 | mount gambier
# Processing Record 13 of Set 10 | la ronge
# Processing Record 14 of Set 10 | katherine
# Processing Record 15 of Set 10 | ust-tsilma
# Processing Record 16 of Set 10 | noumea
# Processing Record 17 of Set 10 | padang
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 10 | logrono
# Processing Record 19 of Set 10 | cayenne
# Processing Record 20 of Set 10 | voh
# Processing Record 21 of Set 10 | palmer
# Processing Record 22 of Set 10 | cadillac
# Processing Record 23 of Set 10 | luau
# Processing Record 24 of Set 10 | kulhudhuffushi
# Processing Record 25 of Set 10 | huarmey
# Processing Record 26 of Set 10 | lawrence
# Processing Record 27 of Set 10 | salvador
# Processing Record 28 of Set 10 | coahuayana
# Processing Record 29 of Set 10 | kisangani
# Processing Record 30 of Set 10 | lagoa
# Processing Record 31 of Set 10 | koslan
# Processing Record 32 of Set 10 | kalga
# Processing Record 33 of Set 10 | ubauro
# Processing Record 34 of Set 10 | seminole
# Processing Record 35 of Set 10 | auki
# Processing Record 36 of Set 10 | burnie
# Processing Record 37 of Set 10 | ivanava
# Processing Record 38 of Set 10 | rio grande
# Processing Record 39 of Set 10 | ziniare
# Processing Record 40 of Set 10 | pitimbu
# Processing Record 41 of Set 10 | toro
# Processing Record 42 of Set 10 | banda aceh
# Processing Record 43 of Set 10 | kristianstad
# Processing Record 44 of Set 10 | lasa
# City not found. Skipping...
# Processing Record 45 of Set 10 | ust-nera
# City not found. Skipping...
# Processing Record 46 of Set 10 | yumen
# Processing Record 47 of Set 10 | charlestown
# Processing Record 48 of Set 10 | kafanchan
# Processing Record 49 of Set 10 | sterlibashevo
# Processing Record 50 of Set 10 | sabang
# Processing Record 1 of Set 11 | pochutla
# Processing Record 2 of Set 11 | sereflikochisar
# City not found. Skipping...
# Processing Record 3 of Set 11 | cascavel
# Processing Record 4 of Set 11 | koumac
# Processing Record 5 of Set 11 | lodja
# Processing Record 6 of Set 11 | tazovskiy
# Processing Record 7 of Set 11 | mamonovo
# Processing Record 8 of Set 11 | taunggyi
# Processing Record 9 of Set 11 | honiara
# Processing Record 10 of Set 11 | parana
# Processing Record 11 of Set 11 | broome
# Processing Record 12 of Set 11 | dehui
# Processing Record 13 of Set 11 | sarankhola
# Processing Record 14 of Set 11 | san andres
# Processing Record 15 of Set 11 | elliot lake
# Processing Record 16 of Set 11 | poum
# Processing Record 17 of Set 11 | maryville
# Processing Record 18 of Set 11 | rudolstadt
# Processing Record 19 of Set 11 | murici
# Processing Record 20 of Set 11 | blagoyevo
# Processing Record 21 of Set 11 | gao
# Processing Record 22 of Set 11 | lerwick
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | la sarre
# Processing Record 25 of Set 11 | montepulciano
# City not found. Skipping...
# Processing Record 26 of Set 11 | tarakan
# Processing Record 27 of Set 11 | aiquile
# City not found. Skipping...
# Processing Record 28 of Set 11 | pathein
# Processing Record 29 of Set 11 | nalut
# Processing Record 30 of Set 11 | worland
# Processing Record 31 of Set 11 | petropavlovka
# Processing Record 32 of Set 11 | oktyabrskoye
# Processing Record 33 of Set 11 | mehamn
# Processing Record 34 of Set 11 | romny
# Processing Record 35 of Set 11 | prachuap khiri khan
# Processing Record 36 of Set 11 | tura
# Processing Record 37 of Set 11 | safford
# Processing Record 38 of Set 11 | russell
# Processing Record 39 of Set 11 | ordynskoye
# Processing Record 40 of Set 11 | dahra
# Processing Record 41 of Set 11 | zeya
# Processing Record 42 of Set 11 | terra nova
# Processing Record 43 of Set 11 | podgornoye
# Processing Record 44 of Set 11 | coquimbo
# Processing Record 45 of Set 11 | juneau
# Processing Record 46 of Set 11 | trelew
# Processing Record 47 of Set 11 | berzence
# Processing Record 48 of Set 11 | bahawalnagar
# Processing Record 49 of Set 11 | santa cruz cabralia
# Processing Record 50 of Set 11 | tricase
# City not found. Skipping...
# Processing Record 1 of Set 12 | kasongo-lunda
# Processing Record 2 of Set 12 | esperance
# Processing Record 3 of Set 12 | qingyuan
# Processing Record 4 of Set 12 | tecoanapa
# City not found. Skipping...
# Processing Record 5 of Set 12 | ulladulla
# Processing Record 6 of Set 12 | santiago do cacem
# Processing Record 7 of Set 12 | ucluelet
# Processing Record 8 of Set 12 | toora-khem
# Processing Record 9 of Set 12 | quatre cocos
# Processing Record 10 of Set 12 | alyangula
# Processing Record 11 of Set 12 | kitaibaraki
# Processing Record 12 of Set 12 | leninskoye
# Processing Record 13 of Set 12 | oriximina
# Processing Record 14 of Set 12 | linhares
# Processing Record 15 of Set 12 | bhachau
# Processing Record 16 of Set 12 | panlaitan
# City not found. Skipping...
# Processing Record 17 of Set 12 | mikun
# City not found. Skipping...
# Processing Record 18 of Set 12 | hede
# Processing Record 19 of Set 12 | constitucion
# Processing Record 20 of Set 12 | dargaville

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(weather_info)

weather_df.columns =["City", "Cloudiness", "Country", "Date", "Humidity", 
                     "Lat", "Lng", "Max Temp", "Wind Speed"]

weather_df.to_csv('Weather_Info.csv', index=False)

weather_df.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Lat           570
# Lng           570
# Max Temp      570
# Wind Speed    570
# dtype: int64

# %%
weather_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     fairbanks          90      US  1540681080        95  64.84 -147.72
# 1  kruisfontein           0      ZA  1540682867        85 -34.00   24.73
# 2         pevek          48      RU  1540682822       100  69.70  170.27
# 3   yellowknife          90      CA  1540681200        93  62.45 -114.38
# 4        tiarei          40      PF  1540681200        70 -17.53 -149.33
#
#    Max Temp  Wind Speed
# 0     32.00        3.62
# 1     62.83       13.24
# 2     14.55       11.23
# 3     32.00        8.05
# 4     86.00       11.41

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker="o", color='c',
            edgecolor='black', alpha=0.7)
plt.title('City Latitude vs. Max Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o", color='c',
            edgecolor='black', alpha=0.7)
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o", color='c',
            edgecolor='black', alpha=0.7)
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o", color='c',
            edgecolor='black', alpha=0.7)
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (MPH)')
plt.grid()
